# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %%
import random
print(random.randint(1, 6))
# Out:
# 6

# %%
import random
import matplotlib.pyplot as plt
dice = []
for i in range(1000000):
  dice.append(random.randint(1,6))
plt.hist(dice, bins = 6)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/gdrive/My Drive/mda/seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)
sep = [] # 8월의 최고 기온 값을 저장할 aug 리스트 생성

for row in data:
  month = row[0].split('-')[1] # -로 구분된 값 중 2번째 값을 month에 저장
  if row[-1] != '':
    if month == '09':
      sep.append(float(row[-1])) # sep 리스트에 최고 기온 값 추가
  
    

plt.hist(sep, bins= 100, color = 'r')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-84eff2822137> in <module>()
#      13       sep.append(float(row[-1])) # sep 리스트에 최고 기온 값 추가
#      14
# ---> 15     result.append(float(row[-1]))
#      16
#      17 plt.hist(sep, bins= 100, color = 'r')
#
# NameError: name 'result' is not defined

# %%
# 1월과 8월의 데이터를 히스토그램으로 시각화하기                                                                              ㅈ
import csv
import matplotlib.pyplot as plt

f = open('/content/gdrive/My Drive/mda/seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

aug = [] # 8월의 최고 기온 값을 저장할 aug 리스트 생성
jan = [] # 1월의 최고 기온 값을 저장할 jan 리스트 생성

for row in data:
  month = row[0].split('-')[1] # -로 구분된 값 중 2번째 값을 motnh에 저장
  if row[-1] != '':
    if month == '08': # 8월달이라면
      aug.append(float(row[-1])) # aug 리스트에 최고 기온 값 추가
    if month == '01':
      jan.append(float(row[-1])) # jan 리스트에 최고 기온 값 추가
      
plt.hist(aug, bins = 100, color = 'r', label = 'Aug')
plt.hist(jan, bins = 100, color = 'r', label = 'Jan')
plt.legend
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/gdrive/My Drive/mda/seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

aug = [] # 8월 달에 최고 기온을 저장할 리스트를 생성
jan = [] # 1월 달에 최고 기온을 저장할 리스트를 생성

for row in data:
  month = row[0].split('-')[1]
  if row[-1] != '':
    if month == '08':
      aug.append(float(row[-1])) # 8월 최고 기온을 추가 
    if month == '01':
      jan.append(float(row[-1])) # 1월 최고 기온 추가
                

plt.hist(aug, bins = 100, color = 'r', label = 'Aug')
plt.hist(jan, bins = 100, color = 'r', label = 'Jan')
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/gdrive/My Drive/mda/seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

aug = []
jan = []

for row in data:
  month = row[0].split('-')[1] # month 저장
  if row[-1] != '':
    if month == '08':
      aug.append(float(row[-1]))
    if month == '01':
      jan.append(float(row[-1]))
      
plt.hist(aug, bins = 100, color = 'g', label = 'Aug')
plt.hist(jan, bins = 100, color = 'g', label = 'Jan')
plt.legend()
plt.show()

# %%
# 기온 데이터를 상자 그림으로 표현하기
import matplotlib.pyplot as plt
import random
import csv 
f = open('/content/gdrive/My Drive/mda/seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data:
  month = row[0].split('-')[1]
  if row[-1] != '':
    if month == '08':
      aug.append(float(row[-1]))
    if month == '01':
      jan.append(float(row[-1]))

plt.boxplot([aug, jan])
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

f = open('/content/gdrive/My Drive/mda/seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

# 월별 데이터를 저장할 리스트 month 생성(12개)
month = [[], [], [], [], [], [], [], [], [], [], [], []]

for row in data:
  if row[-1] != '':
    # 월과 같은 번호의 인덱스에 월별 데이터 저장(ex) : 1월 -> month[0])
    month[int(row[0].split('-')[1])-1].append(float(row[-1]))
    
plt.boxplot(month)
plt.show()

# %%
# 8월 일별 기온 데이터를 상자 그림으로 표현하기
import matplotlib.pyplot as plt
import csv

f = open('/content/gdrive/My Drive/mda/seoul.csv', encoding = 'cp949')
data = csv.reader(f)
next(data)

day = [] # 일별 데이터를 저장할 리스트 day 생성
for i in range(31):
  day.append([]) # day 리스트 내 31개 리스트 생성

for row in data:
  if row[-1] != '':
    if row[0].split('-')[1] == '08': # 8월이라면
      # 최고 기온 값 저장
      day[int(row[0].split('-')[2])-1].append(float(row[-1])-float(row[-2]))

plt.plot(jan)
plt.show()
