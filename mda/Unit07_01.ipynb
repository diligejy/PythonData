# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# 기본 글꼴 변경
import matplotlib as mpl
mpl.font_manager._rebuild()
mpl.pyplot.rc('font', family='NanumBarunGothic')

# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/gdrive/My Drive/mda/age.csv', encoding = 'cp949')
data = csv.reader(f)
result = []  # 빈 리스트 만들기
name = input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 :")

for row in data:
  if name in row[0]: # 삼성2동이 포함된 행정구역 찾기
    for i in row[3:]: # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
      result.append(int(i)) # 해당 연령의 인구수 리스트에 순서 저장하기
print(result)

plt.rc('font', family = 'NanumBarunGothic')
plt.style.use('ggplot') # 격자 무늬 스타일 지정
plt.title(name + ' 지역의 인구구조')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 :삼성1동
# [99, 94, 86, 132, 86, 99, 103, 104, 104, 103, 112, 128, 119, 116, 148, 160, 158, 167, 208, 206, 181, 218, 183, 207, 242, 207, 214, 226, 213, 244, 209, 220, 216, 212, 205, 242, 233, 245, 223, 245, 227, 225, 216, 242, 231, 233, 224, 298, 292, 302, 281, 234, 218, 242, 255, 255, 232, 207, 241, 224, 205, 227, 192, 206, 177, 164, 177, 113, 116, 153, 116, 134, 121, 95, 89, 95, 91, 77, 67, 68, 52, 42, 29, 28, 20, 24, 19, 16, 17, 18, 10, 16, 12, 4, 7, 3, 5, 1, 3, 1, 5]

# %%
import matplotlib.pyplot as plt
plt.bar([0, 3, 2, 1, 6, 10], [1, 2, 3, 5, 6, 7])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(range(6), [1, 2, 3, 5, 6, 7])
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/gdrive/My Drive/mda/age.csv', encoding = 'cp949')
data = csv.reader(f)
result = []  # 빈 리스트 만들기
name = input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 :")

for row in data:
  if name in row[0]: # 삼성2동이 포함된 행정구역 찾기
    for i in row[3:]: # 0세부터 끝(100세 이상)까지 모든 연령에 대해 반복하기
      result.append(int(i)) # 해당 연령의 인구수 리스트에 순서 저장하기


plt.rc('font', family = 'NanumBarunGothic')
plt.bar(range(101), result)
plt.title(name + ' 지역의 인구구조')
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 :삼성1동

# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# 기본 글꼴 변경
import matplotlib as mpl
mpl.font_manager._rebuild()
mpl.pyplot.rc('font', family='NanumBarunGothic')

# %%
import csv
import matplotlib.pyplot as plt

f = open('/content/gdrive/My Drive/mda/gender.csv', encoding = 'cp949')
data = csv.reader(f)
m = []
f = []
name = input("관심 있는 읍면동을 입력하세요:")
for row in data:
  if name in row[0]:
    for i in range(0, 101):
      m.append(-int(row[i+3]))
      f.append(int(row[-(i+1)]))
f.reverse()

plt.title(name + '지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()
# Out:
# 관심 있는 읍면동을 입력하세요:삼성1동
